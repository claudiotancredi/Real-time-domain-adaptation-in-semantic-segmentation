# %% [markdown]
# <a href="https://colab.research.google.com/github/frarus/AMLexam/blob/main/Real-time%20Domain%20Adaptation%20in%20%20Semantic%20Segmentation%20(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
if not os.path.isdir('./AMLexam'):

  # !git clone 'https://github.com/frarus/AMLexam.git'
# Out:
# Cloning into 'AMLexam'...
# remote: Enumerating objects: 293, done.
# remote: Counting objects: 100% (293/293), done.
# remote: Compressing objects: 100% (223/223), done.
# remote: Total 293 (delta 128), reused 182 (delta 56), pack-reused 0
# Receiving objects: 100% (293/293), 331.81 KiB | 2.81 MiB/s, done.
# Resolving deltas: 100% (128/128), done.

# %%
cd AMLexam/
# Out:
# /content/AMLexam

# %%
cd BiSeNet/
# Out:
# /content/AMLexam/BiSeNet

# %%
# !python trainGTAtoCityscapesSSL.py
# Out:
# epoch 0, lr 0.025000: 100% 1000/1000 [03:33<00:00,  4.69it/s]
# average loss for train : 3.471991
# start val!
# precision per pixel for test: 0.259
# mIoU for validation: 0.049
# iter =        0/      75, loss_segmentation = 2.511 loss_D_trg_fake = 0.686 loss_D = 0.692 loss_seg_trg = 0.000
# epoch 1, lr 0.024700: 100% 1000/1000 [03:19<00:00,  5.00it/s]
# average loss for train : 2.406653
# start val!
# precision per pixel for test: 0.539
# mIoU for validation: 0.164
# iter =        1/      75, loss_segmentation = 2.297 loss_D_trg_fake = 0.673 loss_D = 0.681 loss_seg_trg = 0.000
# epoch 2, lr 0.024399: 100% 1000/1000 [03:22<00:00,  4.93it/s]
# average loss for train : 1.942901
# start val!
# precision per pixel for test: 0.614
# mIoU for validation: 0.187
# iter =        2/      75, loss_segmentation = 1.586 loss_D_trg_fake = 0.720 loss_D = 0.671 loss_seg_trg = 0.000
# epoch 3, lr 0.024098: 100% 1000/1000 [03:22<00:00,  4.93it/s]
# average loss for train : 1.734803
# start val!
# ...

# %%
# !python eval.py
# Out:
# load model from /content/drive/MyDrive/checkpoints_101_sgd_da_DSC_withpseudolabels_LAB/best_crossentropy_loss.pth ...
# The best epoch is 36
# Done!
# start test!
# test: 100% 250/250 [05:38<00:00,  1.35s/it]
# IoU for class road: 0.848
# IoU for class sidewalk: 0.333
# IoU for class building: 0.750
# IoU for class wall: 0.220
# IoU for class fence: 0.093
# IoU for class pole: 0.167
# IoU for class light: 0.091
# IoU for class sign: 0.041
# IoU for class vegetation: 0.792
# IoU for class terrain: 0.298
# IoU for class sky: 0.726
# IoU for class person: 0.339
# IoU for class rider: 0.031
# IoU for class car: 0.717
# IoU for class truck: 0.148
# IoU for class bus: 0.060
# IoU for class train: 0.000
# IoU for class motocycle: 0.069
# IoU for class bicycle: 0.000
# precision per pixel for test: 0.717
# mIoU for validation: 0.301
